# %%
import pandas as pd, numpy as np, matplotlib.pyplot as plt

# %%
datos=pd.read_csv("Sismos CDMX.csv")

# %%
datos.head()
# Out:
#       type properties/FENOMENO properties/FECHA properties/HORA  \
# 0  Feature               Sismo         7/7/1974      9:39:22 AM
# 1  Feature               Sismo        11/7/1974      8:41:52 PM
# 2  Feature               Sismo        12/7/1974      8:26:13 AM
# 3  Feature               Sismo        12/7/1974      8:38:24 AM
# 4  Feature               Sismo       13/07/1974      9:09:59 PM
#
#    properties/MAGNITUD  properties/LATITUD  properties/LONGITUD  \
# 0             2.364015               19.37               -99.17
# 1             2.364015               19.37               -99.20
# 2             2.364015               19.38               -99.08
# 3             2.364015               19.41               -99.16
# 4             2.364015               19.34               -99.14
#
#                    properties/REFERENCIA properties/ESTATUS properties/FUENTE  \
# 0     2 km al NOROESTE de COYOACAN, CDMX           revisado    UNAM, SSN 2022
# ...

# %%
datos.memory_usage(deep=True) #cuánta memoria se ocupa
# Out:
# Index                       128
# type                      21632
# properties/FENOMENO       20974
# properties/FECHA          22461
# properties/HORA           22735
# properties/MAGNITUD       20978
# properties/LATITUD         2704
# properties/LONGITUD        2704
# properties/REFERENCIA     32237
# properties/ESTATUS        21986
# properties/FUENTE         23998
# properties/ID              2704
# properties/FECHA_UTC      22453
# properties/HORA_UTC       22719
# properties/PROFUNDIDA     19952
# properties/OBJECTID        2704
# geometry/type             20956
# geometry/coordinates/0     2704
# geometry/coordinates/1     2704
# properties/alcaldía       22961
# dtype: int64

# %%
datos.dtypes #tipos de datos
# Out:
# type                       object
# properties/FENOMENO        object
# properties/FECHA           object
# properties/HORA            object
# properties/MAGNITUD        object
# properties/LATITUD        float64
# properties/LONGITUD       float64
# properties/REFERENCIA      object
# properties/ESTATUS         object
# properties/FUENTE          object
# properties/ID               int64
# properties/FECHA_UTC       object
# properties/HORA_UTC        object
# properties/PROFUNDIDA      object
# properties/OBJECTID         int64
# geometry/type              object
# geometry/coordinates/0    float64
# geometry/coordinates/1    float64
# properties/alcaldía        object
# dtype: object

# %%
import missingno as msno #ver datos faltantes
msno.matrix(datos)
# Out:
# <AxesSubplot:>

# %%
msno.bar(datos)
# Out:
# <AxesSubplot:>

# %%
datos.isnull().sum() #no hay datos faltantes
# Out:
# type                      0
# properties/FENOMENO       0
# properties/FECHA          0
# properties/HORA           0
# properties/MAGNITUD       0
# properties/LATITUD        0
# properties/LONGITUD       0
# properties/REFERENCIA     0
# properties/ESTATUS        0
# properties/FUENTE         0
# properties/ID             0
# properties/FECHA_UTC      0
# properties/HORA_UTC       0
# properties/PROFUNDIDA     0
# properties/OBJECTID       0
# geometry/type             0
# geometry/coordinates/0    0
# geometry/coordinates/1    0
# properties/alcaldía       0
# dtype: int64

# %%
pip install pandas-profiling
# Out:
# ...
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.24.3
#     Uninstalling numpy-1.24.3:
#       Successfully uninstalled numpy-1.24.3
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Could not install packages due to an OSError: [WinError 5] Access is denied: 'C:\\Users\\kevin\\Dropbox\\Python 3.9\\Lib\\site-packages\\~umpy\\.libs\\libopenblas64__v0.3.21-gcc_10_3_0.dll'
# Consider using the `--user` option or check the permissions.

# %%
pip list
# Out:
# Package                        Version
# ------------------------------ --------------------
# absl-py                        1.4.0
# aiohttp                        3.8.1
# aiosignal                      1.2.0
# alabaster                      0.7.12
# anaconda-client                1.9.0
# anaconda-navigator             2.4.2
# anaconda-project               0.10.2
# anyio                          3.5.0
# appdirs                        1.4.4
# argon2-cffi                    21.3.0
# argon2-cffi-bindings           21.2.0
# arrow                          1.2.2
# astroid                        2.6.6
# astropy                        5.0.4
# asttokens                      2.0.5
# astunparse                     1.6.3
# async-timeout                  4.0.1
# atomicwrites                   1.4.0
# attrs                          21.4.0
# Automat                        20.2.0
# autopep8                       1.6.0
# Babel                          2.9.1
# backcall                       0.2.0
# ...

# %%
#!pip uninstall -y pandas-profiling
# Out:
# Found existing installation: pandas-profiling 3.6.6
# Uninstalling pandas-profiling-3.6.6:
#   Successfully uninstalled pandas-profiling-3.6.6

# %%
pip install --upgrade pandas-profiling
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install ydata-profiling

# %%
#from ydata_profiling import ProfileReport

# %%
datos["properties/MAGNITUD"]=pd.to_numeric(datos["properties/MAGNITUD"],errors="coerce") #quitar cadenas de texto en MAGNITUD

# %%
promedio=datos["properties/MAGNITUD"].mean() #con la media se hará la imputación de datos

# %%
datos['properties/MAGNITUD'].fillna(promedio, inplace=True) #imputación de media

# %%
import seaborn as  sns

# %%
sns.pairplot(datos) #datos columna numérica por columna numérica

# %%
sns.pairplot(datos,hue="properties/alcaldía")

# %%
#datos[datos.index.duplicated()]

# %%
datos.corr()
# Out:
#                         properties/MAGNITUD  properties/LATITUD  \
# properties/MAGNITUD                1.000000           -0.267982
# properties/LATITUD                -0.267982            1.000000
# properties/LONGITUD                0.398213           -0.318457
# properties/ID                     -0.425088            0.266767
# properties/OBJECTID               -0.425088            0.266767
# geometry/coordinates/0             0.398213           -0.318457
# geometry/coordinates/1            -0.267982            1.000000
#
#                         properties/LONGITUD  properties/ID  \
# properties/MAGNITUD                0.398213      -0.425088
# properties/LATITUD                -0.318457       0.266767
# properties/LONGITUD                1.000000      -0.117229
# properties/ID                     -0.117229       1.000000
# properties/OBJECTID               -0.117229       1.000000
# geometry/coordinates/0             1.000000      -0.117229
# ...

# %%
sns.jointplot("properties/MAGNITUD","properties/LATITUD",datos)
# Out:
# C:\Users\kevin\Dropbox\Python 3.9\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y, data. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.jointplot("properties/MAGNITUD","properties/LATITUD",datos,kind="reg")
# Out:
# C:\Users\kevin\Dropbox\Python 3.9\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y, data. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.heatmap(datos.corr(),square=True)
# Out:
# <AxesSubplot:>

# %%
sns.heatmap(datos.corr().abs().round(2),square=True,annot=True)
# Out:
# <AxesSubplot:>

# %%
datos.describe()
# Out:
#        properties/MAGNITUD  properties/LATITUD  properties/LONGITUD  \
# count           338.000000          338.000000           338.000000
# mean              2.364015           19.324516           -99.151365
# std               0.653972            0.095185             0.098004
# min               0.300000           19.090000           -99.390000
# 25%               2.000000           19.254600           -99.210000
# 50%               2.364015           19.350000           -99.165600
# 75%               2.700000           19.395525           -99.097600
# max               4.000000           19.520000           -98.944300
#
#        properties/ID  properties/OBJECTID  geometry/coordinates/0  \
# count     338.000000           338.000000              338.000000
# mean      169.500000           169.500000              -99.151365
# std        97.716426            97.716426                0.098004
# min         1.000000             1.000000              -99.390000
# ...

# %%
datos.groupby("properties/alcaldía").mean()
# Out:
#                      properties/MAGNITUD  properties/LATITUD  \
# properties/alcaldía
# ALVARO OBREGON                  2.216736           19.392104
# AZCAPOTZALCO                    2.352803           19.485060
# BENITO JUAREZ                   2.386136           19.391900
# COYOACAN                        2.167275           19.344633
# CUAJIMALPA                      2.004628           19.319513
# CUAUHTEMOC                      2.442677           19.446667
# GUSTAVO A. MADERO               2.602156           19.481300
# IZTACALCO                       2.196212           19.394737
# IZTAPALAPA                      2.068535           19.359480
# MAGDALENA CONTRERAS             2.283144           19.348236
# MIGUEL HIDALGO                  2.098106           19.415758
# MILPA ALTA                      2.922348           19.184855
# TLAHUAC                         2.932576           19.209379
# TLALPAN                         2.408462           19.212659
# ...
